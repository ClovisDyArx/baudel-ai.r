# %%
import pandas as pd

# %%
df_poetry = pd.read_csv("hf://datasets/merve/poetry/poetry.csv")

# %%
df_poetry
# Out:
#                                       author  \
# 0                        WILLIAM SHAKESPEARE
# 1    DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                             THOMAS BASTARD
# 3                             EDMUND SPENSER
# 4                          RICHARD BARNFIELD
# ..                                       ...
# 568                            SARA TEASDALE
# 569                               HART CRANE
# 570                     WILLIAM BUTLER YEATS
# 571                            CARL SANDBURG
# 572                        RICHARD ALDINGTON
#
#                                                content  \
# 0    Let the bird of loudest lay\r\nOn the sole Ara...
# 1    Sir Charles into my chamber coming in,\r\nWhen...
# 2    Our vice runs beyond all that old men saw,\r\n...
# 3    Lo I the man, whose Muse whilome did maske,\r\...
# 4    Long have I longd to see my love againe,\r\nSt...
# ..                                                 ...
# ...

# %%
df_poetry['type'].unique()
# Out:
# array(['Mythology & Folklore', 'Nature', 'Love'], dtype=object)

# %%
df_poetry[df_poetry['type'] == 'Nature']
# Out:
#                   author                                            content  \
# 19   WILLIAM SHAKESPEARE  Why didst thou promise such a beauteous day,\r...
# 20        THOMAS BASTARD  The welcome Sun from sea Freake is returned,\r...
# 21        THOMAS BASTARD  I met a courtier riding on the plain,\r\nWell-...
# 22        THOMAS BASTARD  Walking the fields a wantcatcher I spied,\r\nT...
# 23        THOMAS BASTARD  Fishing, if I a fisher may protest,\r\nOf plea...
# ..                   ...                                                ...
# 485        CARL SANDBURG  Momus is the name men give your face,\r\nThe b...
# 486        CARL SANDBURG  I shall foot it\r\nDown the roadway in the dus...
# 487    RICHARD ALDINGTON  I have sat here happy in the gardens,\r\nWatch...
# 488    RICHARD ALDINGTON  Potuia, potuia\r\nWhite grave goddess,\r\nPity...
# 489    RICHARD ALDINGTON  The ancient songs\r\nPass deathward mournfully...
#
# ...

# %%
df_poetry[df_poetry['type'] == 'Love']
# Out:
#                    author                                            content  \
# 72    WILLIAM SHAKESPEARE  Why didst thou promise such a beauteous day,\r...
# 73    WILLIAM SHAKESPEARE  Weret aught to me I bore the canopy,\r\nWith m...
# 74    WILLIAM SHAKESPEARE  Let the bird of loudest lay\r\nOn the sole Ara...
# 75       GEORGE GASCOIGNE       Sing lullaby, as women do,\r\nWherewith t...
# 76    WILLIAM SHAKESPEARE  Beshrew that heart that makes my heart to groa...
# ..                    ...                                                ...
# 568         SARA TEASDALE  With the man I love who loves me not,\r\nI wal...
# 569            HART CRANE  Hart Crane, "Voyages I, II, III, IV, V, VI" fr...
# 570  WILLIAM BUTLER YEATS  When you are old and grey and full of sleep,\r...
# 571         CARL SANDBURG  Give me hunger,\r\nO you gods that sit and giv...
# 572     RICHARD ALDINGTON  Potuia, potuia\r\nWhite grave goddess,\r\nPity...
#
# ...

# %%
df_poetry[df_poetry['type'] == 'Mythology & Folklore']
# Out:
#                                       author  \
# 0                        WILLIAM SHAKESPEARE
# 1    DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                             THOMAS BASTARD
# 3                             EDMUND SPENSER
# 4                          RICHARD BARNFIELD
# 5                          RICHARD BARNFIELD
# 6                          SIR WALTER RALEGH
# 7                          QUEEN ELIZABETH I
# 8                                 JOHN DONNE
# 9                               JOHN SKELTON
# 10                            EDMUND SPENSER
# 11                       CHRISTOPHER MARLOWE
# 12                            EDMUND SPENSER
# 13                            EDMUND SPENSER
# 14                            EDMUND SPENSER
# 15                            EDMUND SPENSER
# 16                                JOHN DONNE
# 17                       WILLIAM SHAKESPEARE
# 18                       WILLIAM SHAKESPEARE
# 315                        EDGAR LEE MASTERS
# ...

# %%
len(df_poetry['content'].unique())
# Out:
# 506

# %%
len(df_poetry)
# Out:
# 573

# %%
# I want to check the duplicates in the content columns:
dupes = df_poetry[df_poetry.duplicated(subset=['content'])]

# %%
dupes['type'].unique()
# Out:
# array(['Nature', 'Love'], dtype=object)

# %%
df = df_poetry['content']

# %%
df.drop_duplicates(inplace=True)
df
# Out:
# 0      Let the bird of loudest lay\r\nOn the sole Ara...
# 1      Sir Charles into my chamber coming in,\r\nWhen...
# 2      Our vice runs beyond all that old men saw,\r\n...
# 3      Lo I the man, whose Muse whilome did maske,\r\...
# 4      Long have I longd to see my love againe,\r\nSt...
#                              ...
# 565    This youth too long has heard the break\r\nOf ...
# 566    Making his advances\r\nHe does not look at her...
# 567    I thought he was dumb,\r\nI said he was dumb,\...
# 568    With the man I love who loves me not,\r\nI wal...
# 570    When you are old and grey and full of sleep,\r...
# Name: content, Length: 506, dtype: object
